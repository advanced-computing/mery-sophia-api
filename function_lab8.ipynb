# %%
# import libraries
import pandas as pd
import duckdb

# %%
# get data function
DF = pd.read_csv("PCPI25M2.csv")
DF.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 937 entries, 0 to 936
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    937 non-null    str
#  1   CPI     937 non-null    float64
# dtypes: float64(1), str(1)
# memory usage: 14.8 KB

# %%
# get data function
DF = pd.read_csv("PCPI24M1.csv")
DF.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    924 non-null    str
#  1   CPI     924 non-null    float64
# dtypes: float64(1), str(1)
# memory usage: 14.6 KB
